# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import gc

import lightgbm as lgb

from sklearn.metrics import roc_auc_score,accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold

from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder

import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_columns', None)

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
features = train.columns.drop(['id','Target'])

X_test = test[features]
X = train[features]
y = train['Target']

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %%
params = {'n_estimators': 8000, 
          'num_class': 3,
          'boosting_type': 'gbdt',
          'objective': 'multiclass',
          'metric': 'multi_logloss',
          'verbosity': -1,
          'random_state': 42, 
          'reg_alpha': 2.1878527151970849, 
          'reg_lambda': 2.991543710164331, 
          'colsample_bytree': 0.5, 
          'subsample': 0.5, 
          'learning_rate': 0.02, 
          'max_depth': 15, 
          'num_leaves': 60, 
          'min_child_samples': 30, 
          'min_data_per_groups': 15
         }

# %%
def cross_val_train(X, y, test, params):
    
    spl=10   # Number of folders
    
    # Inititate arrays with predictions and oof predictions
    test_preds = np.zeros((len(test),3))
    val_preds = np.zeros((len(X),3))
    val_scores, train_scores = [],[]
    
    # perform cross-validation split
    cv = KFold(spl, shuffle=True, random_state=42)
    
    # "for" cycle to train for each fold
    for fold, (train_ind, valid_ind) in enumerate(cv.split(X,y)):
        
        # divide train and validation data
        X_train = X.iloc[train_ind]
        y_train = y[train_ind]
        X_val = X.iloc[valid_ind]
        y_val = y[valid_ind]
        
        # Initiate model lightGBM 
        model = lgb.LGBMClassifier(**params)
        
        # fit the model
        model.fit(X_train, y_train,
                    eval_set=[(X_val, y_val)],
                    callbacks=[lgb.early_stopping(stopping_rounds=70), lgb.log_evaluation(100)]) 
        
        # predictions on train and validation data
        y_pred_trn = model.predict_proba(X_train)
        y_pred_val = model.predict_proba(X_val)
        
        # compute accuracy
        print(X_train.shape)
        print(y_train.shape)
        print(y_pred_trn.shape)
        print(np.argmax(y_pred_trn, axis=1).shape)
        train_acc = accuracy_score(y_train, np.argmax(y_pred_trn, axis=1))
        val_acc = accuracy_score(y_val, np.argmax(y_pred_val, axis=1))
        
        # print partial results for the fold
        print("Fold:",fold, " Train R2:",np.round(train_acc,5), " Val R2:",np.round(val_acc,5))
        
        # compute test predictions and oof predictions
        test_preds += model.predict_proba(test[features])/spl
        val_preds[valid_ind] = model.predict_proba(X_val)
        val_scores.append(val_acc)
        print("-"*50)
        
    return val_scores, val_preds, test_preds

# %%
val_scores, val_preds, test_preds = cross_val_train(X, y, test, params)
# Out:
# Training until validation scores don't improve for 70 rounds
# [100]	valid_0's multi_logloss: 0.488542
# [200]	valid_0's multi_logloss: 0.446398
# [300]	valid_0's multi_logloss: 0.436426
# [400]	valid_0's multi_logloss: 0.433082
# [500]	valid_0's multi_logloss: 0.431334
# [600]	valid_0's multi_logloss: 0.430947
# [700]	valid_0's multi_logloss: 0.430497
# [800]	valid_0's multi_logloss: 0.43024
# Early stopping, best iteration is:
# [817]	valid_0's multi_logloss: 0.430187
# (68866, 36)
# (68866,)
# (68866, 3)
# (68866,)
# Fold: 0  Train R2: 0.8712  Val R2: 0.83338
# --------------------------------------------------
# Training until validation scores don't improve for 70 rounds
# [100]	valid_0's multi_logloss: 0.478098
# [200]	valid_0's multi_logloss: 0.433944
# [300]	valid_0's multi_logloss: 0.42396
# [400]	valid_0's multi_logloss: 0.420533
# [500]	valid_0's multi_logloss: 0.419043
# [600]	valid_0's multi_logloss: 0.418404
# [700]	valid_0's multi_logloss: 0.418085
# [800]	valid_0's multi_logloss: 0.417908
# [900]	valid_0's multi_logloss: 0.417955
# Early stopping, best iteration is:
# [847]	valid_0's multi_logloss: 0.417841
# (68866, 36)
# (68866,)
# (68866, 3)
# (68866,)
# Fold: 1  Train R2: 0.87227  Val R2: 0.83756
# --------------------------------------------------
# Training until validation scores don't improve for 70 rounds
# [100]	valid_0's multi_logloss: 0.466867
# [200]	valid_0's multi_logloss: 0.42517
# [300]	valid_0's multi_logloss: 0.416129
# [400]	valid_0's multi_logloss: 0.413032
# [500]	valid_0's multi_logloss: 0.411626
# [600]	valid_0's multi_logloss: 0.411068
# [700]	valid_0's multi_logloss: 0.410729
# [800]	valid_0's multi_logloss: 0.410643
# Early stopping, best iteration is:
# [750]	valid_0's multi_logloss: 0.41051
# (68866, 36)
# (68866,)
# (68866, 3)
# (68866,)
# Fold: 2  Train R2: 0.86808  Val R2: 0.84592
# --------------------------------------------------
# Training until validation scores don't improve for 70 rounds
# [100]	valid_0's multi_logloss: 0.490856
# [200]	valid_0's multi_logloss: 0.451186
# [300]	valid_0's multi_logloss: 0.443215
# [400]	valid_0's multi_logloss: 0.440819
# [500]	valid_0's multi_logloss: 0.43987
# [600]	valid_0's multi_logloss: 0.439477
# [700]	valid_0's multi_logloss: 0.439264
# Early stopping, best iteration is:
# [688]	valid_0's multi_logloss: 0.439232
# (68866, 36)
# (68866,)
# (68866, 3)
# (68866,)
# Fold: 3  Train R2: 0.86764  Val R2: 0.83037
# --------------------------------------------------
# Training until validation scores don't improve for 70 rounds
# [100]	valid_0's multi_logloss: 0.488247
# [200]	valid_0's multi_logloss: 0.446438
# [300]	valid_0's multi_logloss: 0.437109
# [400]	valid_0's multi_logloss: 0.434273
# [500]	valid_0's multi_logloss: 0.433031
# [600]	valid_0's multi_logloss: 0.432475
# [700]	valid_0's multi_logloss: 0.432227
# [800]	valid_0's multi_logloss: 0.432143
# Early stopping, best iteration is:
# [800]	valid_0's multi_logloss: 0.432143
# (68866, 36)
# (68866,)
# (68866, 3)
# (68866,)
# Fold: 4  Train R2: 0.87098  Val R2: 0.83364
# --------------------------------------------------
# Training until validation scores don't improve for 70 rounds
# [100]	valid_0's multi_logloss: 0.494734
# [200]	valid_0's multi_logloss: 0.457411
# [300]	valid_0's multi_logloss: 0.44977
# [400]	valid_0's multi_logloss: 0.447728
# [500]	valid_0's multi_logloss: 0.446733
# [600]	valid_0's multi_logloss: 0.446226
# Early stopping, best iteration is:
# [619]	valid_0's multi_logloss: 0.446162
# (68866, 36)
# (68866,)
# (68866, 3)
# (68866,)
# Fold: 5  Train R2: 0.86346  Val R2: 0.82344
# --------------------------------------------------
# Training until validation scores don't improve for 70 rounds
# [100]	valid_0's multi_logloss: 0.495455
# [200]	valid_0's multi_logloss: 0.457337
# [300]	valid_0's multi_logloss: 0.448872
# [400]	valid_0's multi_logloss: 0.445682
# [500]	valid_0's multi_logloss: 0.444308
# [600]	valid_0's multi_logloss: 0.443485
# [700]	valid_0's multi_logloss: 0.443126
# [800]	valid_0's multi_logloss: 0.443292
# Early stopping, best iteration is:
# [733]	valid_0's multi_logloss: 0.443108
# (68866, 36)
# (68866,)
# (68866, 3)
# (68866,)
# Fold: 6  Train R2: 0.86883  Val R2: 0.82684
# --------------------------------------------------
# Training until validation scores don't improve for 70 rounds
# [100]	valid_0's multi_logloss: 0.485578
# [200]	valid_0's multi_logloss: 0.443758
# [300]	valid_0's multi_logloss: 0.43417
# [400]	valid_0's multi_logloss: 0.430579
# [500]	valid_0's multi_logloss: 0.428582
# [600]	valid_0's multi_logloss: 0.427726
# [700]	valid_0's multi_logloss: 0.427339
# [800]	valid_0's multi_logloss: 0.427001
# Early stopping, best iteration is:
# [828]	valid_0's multi_logloss: 0.426916
# (68866, 36)
# (68866,)
# (68866, 3)
# (68866,)
# Fold: 7  Train R2: 0.8714  Val R2: 0.83455
# --------------------------------------------------
# Training until validation scores don't improve for 70 rounds
# [100]	valid_0's multi_logloss: 0.481104
# [200]	valid_0's multi_logloss: 0.438047
# [300]	valid_0's multi_logloss: 0.428732
# [400]	valid_0's multi_logloss: 0.424877
# [500]	valid_0's multi_logloss: 0.422912
# [600]	valid_0's multi_logloss: 0.422083
# [700]	valid_0's multi_logloss: 0.421489
# [800]	valid_0's multi_logloss: 0.421204
# [900]	valid_0's multi_logloss: 0.421128
# [1000]	valid_0's multi_logloss: 0.420995
# Early stopping, best iteration is:
# [1020]	valid_0's multi_logloss: 0.420959
# (68867, 36)
# (68867,)
# (68867, 3)
# (68867,)
# Fold: 8  Train R2: 0.87894  Val R2: 0.83349
# --------------------------------------------------
# Training until validation scores don't improve for 70 rounds
# [100]	valid_0's multi_logloss: 0.48438
# [200]	valid_0's multi_logloss: 0.440975
# [300]	valid_0's multi_logloss: 0.431044
# [400]	valid_0's multi_logloss: 0.427702
# [500]	valid_0's multi_logloss: 0.426067
# [600]	valid_0's multi_logloss: 0.42507
# [700]	valid_0's multi_logloss: 0.42465
# [800]	valid_0's multi_logloss: 0.42436
# [900]	valid_0's multi_logloss: 0.424352
# [1000]	valid_0's multi_logloss: 0.424327
# Early stopping, best iteration is:
# [955]	valid_0's multi_logloss: 0.424211
# (68867, 36)
# (68867,)
# (68867, 3)
# (68867,)
# Fold: 9  Train R2: 0.8764  Val R2: 0.83492
# --------------------------------------------------

# %%
val_preds_out = np.argmax(val_preds, axis=1)
accuracy_score(y, val_preds_out)
# Out:
# 0.833411746255783

# %%
y_test=np.argmax(test_preds, axis=1)
y_test
# Out:
# array([0, 2, 2, ..., 0, 0, 0], dtype=int64)

# %%
y_test = label_encoder.inverse_transform(y_test)

# %%
submission = pd.read_csv("sample_submission.csv")
submission['Target'] = y_test
submission.to_csv('submission_second.csv',index=False)
submission
# Out:
#            id    Target
# 0       76518   Dropout
# 1       76519  Graduate
# 2       76520  Graduate
# 3       76521  Graduate
# 4       76522  Enrolled
# ...       ...       ...
# 51007  127525   Dropout
# 51008  127526   Dropout
# 51009  127527   Dropout
# 51010  127528   Dropout
# 51011  127529   Dropout
#
# [51012 rows x 2 columns]
